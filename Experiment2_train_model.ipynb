# %%
import argparse
import keras
import numpy as np

rmse_best = 0.85
rmse_naive = 1.13

def TrainMLP(train_x, train_y, test_x, test_y, fresh_x, fresh_y, emb_dim,
             epochs, batch_size, learning_rate, first_layer_mult):
    """Trains a MLP and computes its RMSE on the given datasets."""
    layer_num_hidden = [first_layer_mult * emb_dim * 2,
                        first_layer_mult * emb_dim * 1,
                        int(first_layer_mult * emb_dim / 2)]

    model = keras.models.Sequential()
    model.add(keras.layers.Flatten(input_shape=(2, emb_dim)))
    for hidden in layer_num_hidden:
        # as suggested in the paper
        model.add(keras.layers.Dense(hidden, activation='relu'))
    model.add(keras.layers.Dense(1, activation='linear'))
    model.summary()
    model.compile(
        loss='mean_squared_error',
        optimizer=keras.optimizers.Adam(lr=learning_rate))  # as suggested

    model.fit(
        train_x, train_y,
        batch_size=batch_size,
        epochs=epochs,
        verbose=0,
        validation_data=(test_x, test_y),
        workers=4,
        use_multiprocessing=True)

    rmse_train = np.sqrt(model.evaluate(train_x, train_y, verbose=2))
    rmse_test = np.sqrt(model.evaluate(test_x, test_y, verbose=2))
    rmse_fresh = np.sqrt(model.evaluate(fresh_x, fresh_y, verbose=2))

    return rmse_train, rmse_test, rmse_fresh

# %%
results = dict()

# %%
embedding_dims = [16, 32, 64, 128]
num_users_ = [4000, 8000, 16000, 32000]
first_layer_mults = [1, 2, 4]
epochs = 32
batch_size = 256
learning_rate = 0.001
dirr = 'datasets'

# %%
dirr = 'datasets'
for embedding_dim in embedding_dims:
    for num_users in num_users_:
        for first_layer_mult in first_layer_mults:
            num_items = num_users
            print('#' * 100)
            print(f'\t{embedding_dim}\t{num_users}\t{first_layer_mult}')
            print()
            load_spec = f'{embedding_dim}_{num_users}_{num_items}'
            train_x = np.load(f'{dirr}/train_x_{load_spec}.npy')
            train_y = np.load(f'{dirr}/train_y_{load_spec}.npy')
            test_x = np.load(f'{dirr}/test_x_{load_spec}.npy')
            test_y = np.load(f'{dirr}/test_y_{load_spec}.npy')
            fresh_x = np.load(f'{dirr}/fresh_x_{load_spec}.npy')
            fresh_y = np.load(f'{dirr}/fresh_y_{load_spec}.npy')
            
            train_rmse, test_rmse, fresh_rmse = TrainMLP(
                        train_x, train_y, test_x, test_y, fresh_x, fresh_y,
                        emb_dim=embedding_dim, epochs=epochs,
                        batch_size=batch_size, learning_rate=learning_rate,
                        first_layer_mult=first_layer_mult)
            
            
            results[f'emb{embedding_dim}_num_u{num_users}_layer_m{first_layer_mult}_mlp_train_rmse'] = train_rmse 
            results[f'emb{embedding_dim}_num_u{num_users}_layer_m{first_layer_mult}_mlp_test_rmse'] = test_rmse 
            results[f'emb{embedding_dim}_num_u{num_users}_layer_m{first_layer_mult}_mlp_fresh_rmse'] = fresh_rmse
# Out:
# ####################################################################################################
# 	16	4000	1
#
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 32)                1056
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 1,729
# Trainable params: 1,729
# Non-trainable params: 0
# _________________________________________________________________
# 11250/11250 - 8s - loss: 0.7916
# 1250/1250 - 1s - loss: 0.8117
# 3125/3125 - 2s - loss: 0.8088
# ####################################################################################################
# 	16	4000	2
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 32)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_6 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 4,737
# Trainable params: 4,737
# Non-trainable params: 0
# _________________________________________________________________
# 11250/11250 - 8s - loss: 0.7306
# 1250/1250 - 1s - loss: 0.7678
# 3125/3125 - 2s - loss: 0.7572
# ####################################################################################################
# 	16	4000	4
#
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_2 (Flatten)          (None, 32)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               4224
# _________________________________________________________________
# dense_9 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 14,593
# Trainable params: 14,593
# Non-trainable params: 0
# _________________________________________________________________
# 11250/11250 - 8s - loss: 0.6937
# 1250/1250 - 1s - loss: 0.7687
# 3125/3125 - 2s - loss: 0.7651
# ####################################################################################################
# 	16	8000	1
#
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_3 (Flatten)          (None, 32)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_13 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_14 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 1,729
# Trainable params: 1,729
# Non-trainable params: 0
# _________________________________________________________________
# 22500/22500 - 16s - loss: 0.7862
# 2500/2500 - 2s - loss: 0.8125
# 3125/3125 - 2s - loss: 0.8043
# ####################################################################################################
# 	16	8000	2
#
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_4 (Flatten)          (None, 32)                0
# _________________________________________________________________
# dense_16 (Dense)             (None, 64)                2112
# _________________________________________________________________
# dense_17 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_18 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 4,737
# Trainable params: 4,737
# Non-trainable params: 0
# _________________________________________________________________
# 22500/22500 - 16s - loss: 0.7322
# 2500/2500 - 2s - loss: 0.7628
# 3125/3125 - 2s - loss: 0.7556
# ####################################################################################################
# 	16	8000	4
#
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_5 (Flatten)          (None, 32)                0
# _________________________________________________________________
# dense_20 (Dense)             (None, 128)               4224
# _________________________________________________________________
# dense_21 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_22 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 14,593
# Trainable params: 14,593
# Non-trainable params: 0
# _________________________________________________________________
# 22500/22500 - 17s - loss: 0.7118
# 2500/2500 - 2s - loss: 0.7641
# 3125/3125 - 2s - loss: 0.7580
# ####################################################################################################
# 	16	16000	1
#
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_6 (Flatten)          (None, 32)                0
# _________________________________________________________________
# dense_24 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_25 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_26 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dense_27 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 1,729
# Trainable params: 1,729
# Non-trainable params: 0
# _________________________________________________________________
# 45000/45000 - 32s - loss: 0.8133
# 5000/5000 - 4s - loss: 0.8222
# 3125/3125 - 2s - loss: 0.8225
# ####################################################################################################
# 	16	16000	2
#
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_7 (Flatten)          (None, 32)                0
# _________________________________________________________________
# dense_28 (Dense)             (None, 64)                2112
# _________________________________________________________________
# dense_29 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_30 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_31 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 4,737
# Trainable params: 4,737
# Non-trainable params: 0
# _________________________________________________________________
# 45000/45000 - 33s - loss: 0.7350
# 5000/5000 - 4s - loss: 0.7478
# 3125/3125 - 2s - loss: 0.7398
# ####################################################################################################
# 	16	16000	4
#
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_8 (Flatten)          (None, 32)                0
# _________________________________________________________________
# dense_32 (Dense)             (None, 128)               4224
# _________________________________________________________________
# dense_33 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_34 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_35 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 14,593
# Trainable params: 14,593
# Non-trainable params: 0
# _________________________________________________________________
# 45000/45000 - 34s - loss: 0.7220
# 5000/5000 - 4s - loss: 0.7464
# 3125/3125 - 2s - loss: 0.7417
# ####################################################################################################
# 	16	32000	1
#
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_9 (Flatten)          (None, 32)                0
# _________________________________________________________________
# dense_36 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_37 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_38 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dense_39 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 1,729
# Trainable params: 1,729
# Non-trainable params: 0
# _________________________________________________________________
# 90000/90000 - 71s - loss: 0.8115
# 10000/10000 - 7s - loss: 0.8192
# 3125/3125 - 2s - loss: 0.8220
# ####################################################################################################
# 	16	32000	2
#
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_10 (Flatten)         (None, 32)                0
# _________________________________________________________________
# dense_40 (Dense)             (None, 64)                2112
# _________________________________________________________________
# dense_41 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_42 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_43 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 4,737
# Trainable params: 4,737
# Non-trainable params: 0
# _________________________________________________________________
# 90000/90000 - 71s - loss: 0.7297
# 10000/10000 - 8s - loss: 0.7369
# 3125/3125 - 2s - loss: 0.7381
# ####################################################################################################
# 	16	32000	4
#
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_11 (Flatten)         (None, 32)                0
# _________________________________________________________________
# dense_44 (Dense)             (None, 128)               4224
# _________________________________________________________________
# dense_45 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_46 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_47 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 14,593
# Trainable params: 14,593
# Non-trainable params: 0
# _________________________________________________________________
# 90000/90000 - 74s - loss: 0.7238
# 10000/10000 - 8s - loss: 0.7378
# 3125/3125 - 3s - loss: 0.7393
# ####################################################################################################
# 	32	4000	1
#
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_12 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dense_48 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_49 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_50 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_51 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 6,785
# Trainable params: 6,785
# Non-trainable params: 0
# _________________________________________________________________
# 11250/11250 - 10s - loss: 0.7622
# 1250/1250 - 1s - loss: 0.8134
# 3125/3125 - 3s - loss: 0.8279
# ####################################################################################################
# 	32	4000	2
#
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_13 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dense_52 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dense_53 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_54 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_55 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 18,689
# Trainable params: 18,689
# Non-trainable params: 0
# _________________________________________________________________
# 11250/11250 - 9s - loss: 0.6946
# 1250/1250 - 1s - loss: 0.8016
# 3125/3125 - 3s - loss: 0.8139
# ####################################################################################################
# 	32	4000	4
#
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_14 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dense_56 (Dense)             (None, 256)               16640
# _________________________________________________________________
# dense_57 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_58 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_59 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 57,857
# Trainable params: 57,857
# Non-trainable params: 0
# _________________________________________________________________
# 11250/11250 - 10s - loss: 0.5702
# 1250/1250 - 1s - loss: 0.8733
# 3125/3125 - 3s - loss: 0.8861
# ####################################################################################################
# 	32	8000	1
#
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_15 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dense_60 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_61 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_62 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_63 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 6,785
# Trainable params: 6,785
# Non-trainable params: 0
# _________________________________________________________________
# 22500/22500 - 16s - loss: 0.7840
# 2500/2500 - 2s - loss: 0.8176
# 3125/3125 - 2s - loss: 0.8313
# ####################################################################################################
# 	32	8000	2
#
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_16 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dense_64 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dense_65 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_66 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_67 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 18,689
# Trainable params: 18,689
# Non-trainable params: 0
# _________________________________________________________________
# 22500/22500 - 18s - loss: 0.7151
# 2500/2500 - 2s - loss: 0.7824
# 3125/3125 - 3s - loss: 0.7812
# ####################################################################################################
# 	32	8000	4
#
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_17 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dense_68 (Dense)             (None, 256)               16640
# _________________________________________________________________
# dense_69 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_70 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_71 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 57,857
# Trainable params: 57,857
# Non-trainable params: 0
# _________________________________________________________________
# 22500/22500 - 20s - loss: 0.6423
# 2500/2500 - 2s - loss: 0.8097
# 3125/3125 - 2s - loss: 0.8128
# ####################################################################################################
# 	32	16000	1
#
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_18 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dense_72 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_73 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_74 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_75 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 6,785
# Trainable params: 6,785
# Non-trainable params: 0
# _________________________________________________________________
# 45000/45000 - 32s - loss: 0.7819
# 5000/5000 - 4s - loss: 0.8020
# 3125/3125 - 2s - loss: 0.8048
# ####################################################################################################
# 	32	16000	2
#
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_19 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dense_76 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dense_77 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_78 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_79 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 18,689
# Trainable params: 18,689
# Non-trainable params: 0
# _________________________________________________________________
# 45000/45000 - 40s - loss: 0.7281
# 5000/5000 - 4s - loss: 0.7671
# 3125/3125 - 3s - loss: 0.7640
# ####################################################################################################
# 	32	16000	4
#
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_20 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dense_80 (Dense)             (None, 256)               16640
# _________________________________________________________________
# dense_81 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_82 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_83 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 57,857
# Trainable params: 57,857
# Non-trainable params: 0
# _________________________________________________________________
# 45000/45000 - 41s - loss: 0.6920
# 5000/5000 - 5s - loss: 0.7712
# 3125/3125 - 4s - loss: 0.7708
# ####################################################################################################
# 	32	32000	1
#
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_21 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dense_84 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_85 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_86 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_87 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 6,785
# Trainable params: 6,785
# Non-trainable params: 0
# _________________________________________________________________
# 90000/90000 - 71s - loss: 0.7913
# 10000/10000 - 7s - loss: 0.8089
# 3125/3125 - 2s - loss: 0.8105
# ####################################################################################################
# 	32	32000	2
#
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_22 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dense_88 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dense_89 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_90 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_91 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 18,689
# Trainable params: 18,689
# Non-trainable params: 0
# _________________________________________________________________
# 90000/90000 - 69s - loss: 0.7359
# 10000/10000 - 8s - loss: 0.7608
# 3125/3125 - 3s - loss: 0.7560
# ####################################################################################################
# 	32	32000	4
#
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_23 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dense_92 (Dense)             (None, 256)               16640
# _________________________________________________________________
# dense_93 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_94 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_95 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 57,857
# Trainable params: 57,857
# Non-trainable params: 0
# _________________________________________________________________
# 90000/90000 - 71s - loss: 0.7165
# 10000/10000 - 8s - loss: 0.7626
# 3125/3125 - 2s - loss: 0.7584
# ####################################################################################################
# 	64	4000	1
#
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_24 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_96 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_97 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_98 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_99 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 26,881
# Trainable params: 26,881
# Non-trainable params: 0
# _________________________________________________________________
# 11250/11250 - 9s - loss: 0.6858
# 1250/1250 - 1s - loss: 0.8752
# 3125/3125 - 2s - loss: 0.9245
# ####################################################################################################
# 	64	4000	2
#
# Model: "sequential_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_25 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_100 (Dense)            (None, 256)               33024
# _________________________________________________________________
# dense_101 (Dense)            (None, 128)               32896
# _________________________________________________________________
# dense_102 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_103 (Dense)            (None, 1)                 65
# =================================================================
# Total params: 74,241
# Trainable params: 74,241
# Non-trainable params: 0
# _________________________________________________________________
# 11250/11250 - 9s - loss: 0.5110
# 1250/1250 - 1s - loss: 0.9573
# 3125/3125 - 3s - loss: 1.0043
# ####################################################################################################
# 	64	4000	4
#
# Model: "sequential_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_26 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_104 (Dense)            (None, 512)               66048
# _________________________________________________________________
# dense_105 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dense_106 (Dense)            (None, 128)               32896
# _________________________________________________________________
# dense_107 (Dense)            (None, 1)                 129
# =================================================================
# Total params: 230,401
# Trainable params: 230,401
# Non-trainable params: 0
# _________________________________________________________________
# 11250/11250 - 12s - loss: 0.2507
# 1250/1250 - 1s - loss: 1.1264
# 3125/3125 - 3s - loss: 1.1882
# ####################################################################################################
# 	64	8000	1
#
# Model: "sequential_27"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_27 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_108 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_109 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_110 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_111 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 26,881
# Trainable params: 26,881
# Non-trainable params: 0
# _________________________________________________________________
# 22500/22500 - 17s - loss: 0.7246
# 2500/2500 - 2s - loss: 0.8285
# 3125/3125 - 2s - loss: 0.8355
# ####################################################################################################
# 	64	8000	2
#
# Model: "sequential_28"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_28 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_112 (Dense)            (None, 256)               33024
# _________________________________________________________________
# dense_113 (Dense)            (None, 128)               32896
# _________________________________________________________________
# dense_114 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_115 (Dense)            (None, 1)                 65
# =================================================================
# Total params: 74,241
# Trainable params: 74,241
# Non-trainable params: 0
# _________________________________________________________________
# 22500/22500 - 18s - loss: 0.6190
# 2500/2500 - 2s - loss: 0.8596
# 3125/3125 - 2s - loss: 0.8695
# ####################################################################################################
# 	64	8000	4
#
# Model: "sequential_29"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_29 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_116 (Dense)            (None, 512)               66048
# _________________________________________________________________
# dense_117 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dense_118 (Dense)            (None, 128)               32896
# _________________________________________________________________
# dense_119 (Dense)            (None, 1)                 129
# =================================================================
# Total params: 230,401
# Trainable params: 230,401
# Non-trainable params: 0
# _________________________________________________________________
# 22500/22500 - 24s - loss: 0.4241
# 2500/2500 - 3s - loss: 0.9825
# 3125/3125 - 3s - loss: 0.9945
# ####################################################################################################
# 	64	16000	1
#
# Model: "sequential_30"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_30 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_120 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_121 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_122 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_123 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 26,881
# Trainable params: 26,881
# Non-trainable params: 0
# _________________________________________________________________
# 45000/45000 - 35s - loss: 0.7494
# 5000/5000 - 4s - loss: 0.8074
# 3125/3125 - 2s - loss: 0.8128
# ####################################################################################################
# 	64	16000	2
#
# Model: "sequential_31"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_31 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_124 (Dense)            (None, 256)               33024
# _________________________________________________________________
# dense_125 (Dense)            (None, 128)               32896
# _________________________________________________________________
# dense_126 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_127 (Dense)            (None, 1)                 65
# =================================================================
# Total params: 74,241
# Trainable params: 74,241
# Non-trainable params: 0
# _________________________________________________________________
# 45000/45000 - 36s - loss: 0.6821
# 5000/5000 - 4s - loss: 0.8026
# 3125/3125 - 2s - loss: 0.8056
# ####################################################################################################
# 	64	16000	4
#
# Model: "sequential_32"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_32 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_128 (Dense)            (None, 512)               66048
# _________________________________________________________________
# dense_129 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dense_130 (Dense)            (None, 128)               32896
# _________________________________________________________________
# dense_131 (Dense)            (None, 1)                 129
# =================================================================
# Total params: 230,401
# Trainable params: 230,401
# Non-trainable params: 0
# _________________________________________________________________
# 45000/45000 - 48s - loss: 0.5731
# 5000/5000 - 5s - loss: 0.8632
# 3125/3125 - 3s - loss: 0.8648
# ####################################################################################################
# 	64	32000	1
#
# Model: "sequential_33"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_33 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_132 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_133 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_134 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_135 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 26,881
# Trainable params: 26,881
# Non-trainable params: 0
# _________________________________________________________________
# 90000/90000 - 68s - loss: 0.7690
# 10000/10000 - 8s - loss: 0.8031
# 3125/3125 - 3s - loss: 0.8161
# ####################################################################################################
# 	64	32000	2
#
# Model: "sequential_34"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_34 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_136 (Dense)            (None, 256)               33024
# _________________________________________________________________
# dense_137 (Dense)            (None, 128)               32896
# _________________________________________________________________
# dense_138 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_139 (Dense)            (None, 1)                 65
# =================================================================
# Total params: 74,241
# Trainable params: 74,241
# Non-trainable params: 0
# _________________________________________________________________
# 90000/90000 - 72s - loss: 0.7191
# 10000/10000 - 8s - loss: 0.7828
# 3125/3125 - 2s - loss: 0.7890
# ####################################################################################################
# 	64	32000	4
#
# Model: "sequential_35"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_35 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_140 (Dense)            (None, 512)               66048
# _________________________________________________________________
# dense_141 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dense_142 (Dense)            (None, 128)               32896
# _________________________________________________________________
# dense_143 (Dense)            (None, 1)                 129
# =================================================================
# Total params: 230,401
# Trainable params: 230,401
# Non-trainable params: 0
# _________________________________________________________________
# 90000/90000 - 97s - loss: 0.6677
# 10000/10000 - 11s - loss: 0.7888
# 3125/3125 - 3s - loss: 0.7971
# ####################################################################################################
# 	128	4000	1
#
# Model: "sequential_36"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_36 (Flatten)         (None, 256)               0
# _________________________________________________________________
# dense_144 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_145 (Dense)            (None, 128)               32896
# _________________________________________________________________
# dense_146 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_147 (Dense)            (None, 1)                 65
# =================================================================
# Total params: 107,009
# Trainable params: 107,009
# Non-trainable params: 0
# _________________________________________________________________
# 11250/11250 - 10s - loss: 0.4386
# 1250/1250 - 1s - loss: 1.1145
# 3125/3125 - 3s - loss: 1.3651
# ####################################################################################################
# 	128	4000	2
#
# Model: "sequential_37"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_37 (Flatten)         (None, 256)               0
# _________________________________________________________________
# dense_148 (Dense)            (None, 512)               131584
# _________________________________________________________________
# dense_149 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dense_150 (Dense)            (None, 128)               32896
# _________________________________________________________________
# dense_151 (Dense)            (None, 1)                 129
# =================================================================
# Total params: 295,937
# Trainable params: 295,937
# Non-trainable params: 0
# _________________________________________________________________
# 11250/11250 - 13s - loss: 0.1771
# 1250/1250 - 1s - loss: 1.2788
# 3125/3125 - 4s - loss: 1.4714
# ####################################################################################################
# 	128	4000	4
#
# Model: "sequential_38"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_38 (Flatten)         (None, 256)               0
# _________________________________________________________________
# dense_152 (Dense)            (None, 1024)              263168
# _________________________________________________________________
# dense_153 (Dense)            (None, 512)               524800
# _________________________________________________________________
# dense_154 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dense_155 (Dense)            (None, 1)                 257
# =================================================================
# Total params: 919,553
# Trainable params: 919,553
# Non-trainable params: 0
# _________________________________________________________________
# 11250/11250 - 19s - loss: 0.0774
# 1250/1250 - 2s - loss: 1.1633
# 3125/3125 - 5s - loss: 1.2607
# ####################################################################################################
# 	128	8000	1
#
# Model: "sequential_39"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_39 (Flatten)         (None, 256)               0
# _________________________________________________________________
# dense_156 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_157 (Dense)            (None, 128)               32896
# _________________________________________________________________
# dense_158 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_159 (Dense)            (None, 1)                 65
# =================================================================
# Total params: 107,009
# Trainable params: 107,009
# Non-trainable params: 0
# _________________________________________________________________
# 22500/22500 - 20s - loss: 0.5893
# 2500/2500 - 2s - loss: 0.9650
# 3125/3125 - 3s - loss: 1.1123
# ####################################################################################################
# 	128	8000	2
#
# Model: "sequential_40"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_40 (Flatten)         (None, 256)               0
# _________________________________________________________________
# dense_160 (Dense)            (None, 512)               131584
# _________________________________________________________________
# dense_161 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dense_162 (Dense)            (None, 128)               32896
# _________________________________________________________________
# dense_163 (Dense)            (None, 1)                 129
# =================================================================
# Total params: 295,937
# Trainable params: 295,937
# Non-trainable params: 0
# _________________________________________________________________
# 22500/22500 - 26s - loss: 0.3499
# 2500/2500 - 3s - loss: 1.1045
# 3125/3125 - 4s - loss: 1.2145
# ####################################################################################################
# 	128	8000	4
#
# Model: "sequential_41"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_41 (Flatten)         (None, 256)               0
# _________________________________________________________________
# dense_164 (Dense)            (None, 1024)              263168
# _________________________________________________________________
# dense_165 (Dense)            (None, 512)               524800
# _________________________________________________________________
# dense_166 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dense_167 (Dense)            (None, 1)                 257
# =================================================================
# Total params: 919,553
# Trainable params: 919,553
# Non-trainable params: 0
# _________________________________________________________________
# 22500/22500 - 42s - loss: 0.1431
# 2500/2500 - 4s - loss: 1.2242
# 3125/3125 - 5s - loss: 1.2998
# ####################################################################################################
# 	128	16000	1
#
# Model: "sequential_42"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_42 (Flatten)         (None, 256)               0
# _________________________________________________________________
# dense_168 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_169 (Dense)            (None, 128)               32896
# _________________________________________________________________
# dense_170 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_171 (Dense)            (None, 1)                 65
# =================================================================
# Total params: 107,009
# Trainable params: 107,009
# Non-trainable params: 0
# _________________________________________________________________
# 45000/45000 - 44s - loss: 0.6793
# 5000/5000 - 5s - loss: 0.8766
# 3125/3125 - 3s - loss: 0.9142
# ####################################################################################################
# 	128	16000	2
#
# Model: "sequential_43"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_43 (Flatten)         (None, 256)               0
# _________________________________________________________________
# dense_172 (Dense)            (None, 512)               131584
# _________________________________________________________________
# dense_173 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dense_174 (Dense)            (None, 128)               32896
# _________________________________________________________________
# dense_175 (Dense)            (None, 1)                 129
# =================================================================
# Total params: 295,937
# Trainable params: 295,937
# Non-trainable params: 0
# _________________________________________________________________
# 45000/45000 - 51s - loss: 0.5224
# 5000/5000 - 6s - loss: 0.9349
# 3125/3125 - 4s - loss: 0.9604
# ####################################################################################################
# 	128	16000	4
#
# Model: "sequential_44"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_44 (Flatten)         (None, 256)               0
# _________________________________________________________________
# dense_176 (Dense)            (None, 1024)              263168
# _________________________________________________________________
# dense_177 (Dense)            (None, 512)               524800
# _________________________________________________________________
# dense_178 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dense_179 (Dense)            (None, 1)                 257
# =================================================================
# Total params: 919,553
# Trainable params: 919,553
# Non-trainable params: 0
# _________________________________________________________________
# 45000/45000 - 98s - loss: 0.3336
# 5000/5000 - 11s - loss: 1.0851
# 3125/3125 - 7s - loss: 1.1215
# ####################################################################################################
# 	128	32000	1
#
# Model: "sequential_45"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_45 (Flatten)         (None, 256)               0
# _________________________________________________________________
# dense_180 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_181 (Dense)            (None, 128)               32896
# _________________________________________________________________
# dense_182 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_183 (Dense)            (None, 1)                 65
# =================================================================
# Total params: 107,009
# Trainable params: 107,009
# Non-trainable params: 0
# _________________________________________________________________
# 90000/90000 - 110s - loss: 0.7313
# 10000/10000 - 12s - loss: 0.8376
# 3125/3125 - 4s - loss: 0.8567
# ####################################################################################################
# 	128	32000	2
#
# Model: "sequential_46"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_46 (Flatten)         (None, 256)               0
# _________________________________________________________________
# dense_184 (Dense)            (None, 512)               131584
# _________________________________________________________________
# dense_185 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dense_186 (Dense)            (None, 128)               32896
# _________________________________________________________________
# dense_187 (Dense)            (None, 1)                 129
# =================================================================
# Total params: 295,937
# Trainable params: 295,937
# Non-trainable params: 0
# _________________________________________________________________
# 90000/90000 - 137s - loss: 0.6483
# 10000/10000 - 15s - loss: 0.8386
# 3125/3125 - 5s - loss: 0.8528
# ####################################################################################################
# 	128	32000	4
#
# Model: "sequential_47"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_47 (Flatten)         (None, 256)               0
# _________________________________________________________________
# dense_188 (Dense)            (None, 1024)              263168
# _________________________________________________________________
# dense_189 (Dense)            (None, 512)               524800
# _________________________________________________________________
# dense_190 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dense_191 (Dense)            (None, 1)                 257
# =================================================================
# Total params: 919,553
# Trainable params: 919,553
# Non-trainable params: 0
# _________________________________________________________________
# 90000/90000 - 209s - loss: 0.5200
# 10000/10000 - 22s - loss: 0.8953
# 3125/3125 - 7s - loss: 0.9108

# %%
results
# Out:
# {'emb16_num_u4000_layer_m1_mlp_train_rmse': 0.889709604549457,
#  'emb16_num_u4000_layer_m1_mlp_test_rmse': 0.9009705039498126,
#  'emb16_num_u4000_layer_m1_mlp_fresh_rmse': 0.8993258852401651,
#  'emb16_num_u4000_layer_m2_mlp_train_rmse': 0.8547316558980413,
#  'emb16_num_u4000_layer_m2_mlp_test_rmse': 0.8762250226823906,
#  'emb16_num_u4000_layer_m2_mlp_fresh_rmse': 0.8701945226619235,
#  'emb16_num_u4000_layer_m4_mlp_train_rmse': 0.8329065223280918,
#  'emb16_num_u4000_layer_m4_mlp_test_rmse': 0.8767599390063179,
#  'emb16_num_u4000_layer_m4_mlp_fresh_rmse': 0.8747042428581561,
#  'emb16_num_u8000_layer_m1_mlp_train_rmse': 0.8866623175724706,
#  'emb16_num_u8000_layer_m1_mlp_test_rmse': 0.9013681132765424,
#  'emb16_num_u8000_layer_m1_mlp_fresh_rmse': 0.8968451943578792,
#  'emb16_num_u8000_layer_m2_mlp_train_rmse': 0.8557154678545356,
#  'emb16_num_u8000_layer_m2_mlp_test_rmse': 0.8733845853387373,
#  'emb16_num_u8000_layer_m2_mlp_fresh_rmse': 0.8692676237095447,
#  'emb16_num_u8000_layer_m4_mlp_train_rmse': 0.8436709472922442,
#  'emb16_num_u8000_layer_m4_mlp_test_rmse': 0.8741517723955325,
#  'emb16_num_u8000_layer_m4_mlp_fresh_rmse': 0.8706283694692942,
#  'emb16_num_u16000_layer_m1_mlp_train_rmse': 0.9018292632372135,
#  'emb16_num_u16000_layer_m1_mlp_test_rmse': 0.9067722657243669,
#  'emb16_num_u16000_layer_m1_mlp_fresh_rmse': 0.906926461671611,
#  'emb16_num_u16000_layer_m2_mlp_train_rmse': 0.8573072352488613,
#  'emb16_num_u16000_layer_m2_mlp_test_rmse': 0.8647314121027462,
#  'emb16_num_u16000_layer_m2_mlp_fresh_rmse': 0.8601097433907252,
#  'emb16_num_u16000_layer_m4_mlp_train_rmse': 0.849699870584556,
#  'emb16_num_u16000_layer_m4_mlp_test_rmse': 0.8639721759404382,
#  'emb16_num_u16000_layer_m4_mlp_fresh_rmse': 0.8612453221940123,
#  'emb16_num_u32000_layer_m1_mlp_train_rmse': 0.9008468828996711,
#  'emb16_num_u32000_layer_m1_mlp_test_rmse': 0.905096273359652,
#  'emb16_num_u32000_layer_m1_mlp_fresh_rmse': 0.9066654108251495,
#  'emb16_num_u32000_layer_m2_mlp_train_rmse': 0.8542135776260608,
#  'emb16_num_u32000_layer_m2_mlp_test_rmse': 0.8584004164532969,
#  'emb16_num_u32000_layer_m2_mlp_fresh_rmse': 0.8591189609927533,
#  'emb16_num_u32000_layer_m4_mlp_train_rmse': 0.8507584441800315,
#  'emb16_num_u32000_layer_m4_mlp_test_rmse': 0.8589413675919113,
#  'emb16_num_u32000_layer_m4_mlp_fresh_rmse': 0.8598330230847893,
#  'emb32_num_u4000_layer_m1_mlp_train_rmse': 0.8730609047805704,
#  'emb32_num_u4000_layer_m1_mlp_test_rmse': 0.9018929746849691,
#  'emb32_num_u4000_layer_m1_mlp_fresh_rmse': 0.9099168585429959,
#  'emb32_num_u4000_layer_m2_mlp_train_rmse': 0.8334102038850726,
#  'emb32_num_u4000_layer_m2_mlp_test_rmse': 0.8953112737038088,
#  'emb32_num_u4000_layer_m2_mlp_fresh_rmse': 0.9021578840912001,
#  'emb32_num_u4000_layer_m4_mlp_train_rmse': 0.7551229669840029,
#  'emb32_num_u4000_layer_m4_mlp_test_rmse': 0.9344834433814114,
#  'emb32_num_u4000_layer_m4_mlp_fresh_rmse': 0.9413421419087707,
#  'emb32_num_u8000_layer_m1_mlp_train_rmse': 0.8854454746421716,
#  'emb32_num_u8000_layer_m1_mlp_test_rmse': 0.9042025160531094,
#  'emb32_num_u8000_layer_m1_mlp_fresh_rmse': 0.9117513276517515,
#  'emb32_num_u8000_layer_m2_mlp_train_rmse': 0.8456502638015331,
#  'emb32_num_u8000_layer_m2_mlp_test_rmse': 0.8845495840226799,
#  'emb32_num_u8000_layer_m2_mlp_fresh_rmse': 0.8838289536383147,
#  'emb32_num_u8000_layer_m4_mlp_train_rmse': 0.8014119339605816,
#  'emb32_num_u8000_layer_m4_mlp_test_rmse': 0.8998486590297072,
#  'emb32_num_u8000_layer_m4_mlp_fresh_rmse': 0.9015389688948077,
#  'emb32_num_u16000_layer_m1_mlp_train_rmse': 0.8842555042858038,
#  'emb32_num_u16000_layer_m1_mlp_test_rmse': 0.8955534046676823,
#  'emb32_num_u16000_layer_m1_mlp_fresh_rmse': 0.8970794697200095,
#  'emb32_num_u16000_layer_m2_mlp_train_rmse': 0.8532994605459334,
#  'emb32_num_u16000_layer_m2_mlp_test_rmse': 0.875821341176299,
#  'emb32_num_u16000_layer_m2_mlp_fresh_rmse': 0.8740471692832602,
#  'emb32_num_u16000_layer_m4_mlp_train_rmse': 0.8318582632557917,
#  'emb32_num_u16000_layer_m4_mlp_test_rmse': 0.8781819728954035,
#  'emb32_num_u16000_layer_m4_mlp_fresh_rmse': 0.8779428924484014,
#  'emb32_num_u32000_layer_m1_mlp_train_rmse': 0.8895735641109837,
#  'emb32_num_u32000_layer_m1_mlp_test_rmse': 0.8993610113777829,
#  'emb32_num_u32000_layer_m1_mlp_fresh_rmse': 0.9002691422799989,
#  'emb32_num_u32000_layer_m2_mlp_train_rmse': 0.8578516202528575,
#  'emb32_num_u32000_layer_m2_mlp_test_rmse': 0.8722217936592372,
#  'emb32_num_u32000_layer_m2_mlp_fresh_rmse': 0.8694824232460374,
#  'emb32_num_u32000_layer_m4_mlp_train_rmse': 0.8464486798064497,
#  'emb32_num_u32000_layer_m4_mlp_test_rmse': 0.8732631679976015,
#  'emb32_num_u32000_layer_m4_mlp_fresh_rmse': 0.8708435178158129,
#  'emb64_num_u4000_layer_m1_mlp_train_rmse': 0.8281419140509944,
#  'emb64_num_u4000_layer_m1_mlp_test_rmse': 0.9355279844921336,
#  'emb64_num_u4000_layer_m1_mlp_fresh_rmse': 0.9614889531961484,
#  'emb64_num_u4000_layer_m2_mlp_train_rmse': 0.7148759344808224,
#  'emb64_num_u4000_layer_m2_mlp_test_rmse': 0.9784173973257733,
#  'emb64_num_u4000_layer_m2_mlp_fresh_rmse': 1.0021556627232049,
#  'emb64_num_u4000_layer_m4_mlp_train_rmse': 0.5007120069697201,
#  'emb64_num_u4000_layer_m4_mlp_test_rmse': 1.0613089786132133,
#  'emb64_num_u4000_layer_m4_mlp_fresh_rmse': 1.0900458145137537,
#  'emb64_num_u8000_layer_m1_mlp_train_rmse': 0.8512289111288106,
#  'emb64_num_u8000_layer_m1_mlp_test_rmse': 0.9102131576101733,
#  'emb64_num_u8000_layer_m1_mlp_fresh_rmse': 0.9140820297371951,
#  'emb64_num_u8000_layer_m2_mlp_train_rmse': 0.7867431924729679,
#  'emb64_num_u8000_layer_m2_mlp_test_rmse': 0.92714127705977,
#  'emb64_num_u8000_layer_m2_mlp_fresh_rmse': 0.9324832840103898,
#  'emb64_num_u8000_layer_m4_mlp_train_rmse': 0.6511973055134147,
#  'emb64_num_u8000_layer_m4_mlp_test_rmse': 0.9912281655002975,
#  'emb64_num_u8000_layer_m4_mlp_fresh_rmse': 0.9972356197805513,
#  'emb64_num_u16000_layer_m1_mlp_train_rmse': 0.865691260270381,
#  'emb64_num_u16000_layer_m1_mlp_test_rmse': 0.8985589650186667,
#  'emb64_num_u16000_layer_m1_mlp_fresh_rmse': 0.901563067245966,
#  'emb64_num_u16000_layer_m2_mlp_train_rmse': 0.8258657767668673,
#  'emb64_num_u16000_layer_m2_mlp_test_rmse': 0.8958884192688958,
#  'emb64_num_u16000_layer_m2_mlp_fresh_rmse': 0.8975391374624423,
#  'emb64_num_u16000_layer_m4_mlp_train_rmse': 0.757049136742763,
#  'emb64_num_u16000_layer_m4_mlp_test_rmse': 0.9290677096326356,
#  'emb64_num_u16000_layer_m4_mlp_fresh_rmse': 0.9299214493485273,
#  'emb64_num_u32000_layer_m1_mlp_train_rmse': 0.8769536687428715,
#  'emb64_num_u32000_layer_m1_mlp_test_rmse': 0.8961630850111357,
#  'emb64_num_u32000_layer_m1_mlp_fresh_rmse': 0.9033853703346069,
#  'emb64_num_u32000_layer_m2_mlp_train_rmse': 0.8480249824667646,
#  'emb64_num_u32000_layer_m2_mlp_test_rmse': 0.88474396601223,
#  'emb64_num_u32000_layer_m2_mlp_fresh_rmse': 0.8882392249319452,
#  'emb64_num_u32000_layer_m4_mlp_train_rmse': 0.8171057373922953,
#  'emb64_num_u32000_layer_m4_mlp_test_rmse': 0.8881626221045785,
#  'emb64_num_u32000_layer_m4_mlp_fresh_rmse': 0.8927824758916283,
#  'emb128_num_u4000_layer_m1_mlp_train_rmse': 0.6622941201080481,
#  'emb128_num_u4000_layer_m1_mlp_test_rmse': 1.0557147074786497,
#  'emb128_num_u4000_layer_m1_mlp_fresh_rmse': 1.1683747469427428,
#  'emb128_num_u4000_layer_m2_mlp_train_rmse': 0.42086037731458475,
#  'emb128_num_u4000_layer_m2_mlp_test_rmse': 1.1308242186251851,
#  'emb128_num_u4000_layer_m2_mlp_fresh_rmse': 1.2129937710110708,
#  'emb128_num_u4000_layer_m4_mlp_train_rmse': 0.27827453236768934,
#  'emb128_num_u4000_layer_m4_mlp_test_rmse': 1.0785524377892324,
#  'emb128_num_u4000_layer_m4_mlp_fresh_rmse': 1.1227963375432723,
#  'emb128_num_u8000_layer_m1_mlp_train_rmse': 0.7676394683165143,
#  'emb128_num_u8000_layer_m1_mlp_test_rmse': 0.9823431813933297,
#  'emb128_num_u8000_layer_m1_mlp_fresh_rmse': 1.0546547213511683,
#  'emb128_num_u8000_layer_m2_mlp_train_rmse': 0.5915144192783365,
#  'emb128_num_u8000_layer_m2_mlp_test_rmse': 1.0509679125089757,
#  'emb128_num_u8000_layer_m2_mlp_fresh_rmse': 1.102061273730235,
#  'emb128_num_u8000_layer_m4_mlp_train_rmse': 0.3782465786586918,
#  'emb128_num_u8000_layer_m4_mlp_test_rmse': 1.10643631610765,
#  'emb128_num_u8000_layer_m4_mlp_fresh_rmse': 1.1400739305348868,
#  'emb128_num_u16000_layer_m1_mlp_train_rmse': 0.8241877979414854,
#  'emb128_num_u16000_layer_m1_mlp_test_rmse': 0.9362671693416815,
#  'emb128_num_u16000_layer_m1_mlp_fresh_rmse': 0.95614177864385,
#  'emb128_num_u16000_layer_m2_mlp_train_rmse': 0.7227602084879474,
#  'emb128_num_u16000_layer_m2_mlp_test_rmse': 0.9668920296745585,
#  'emb128_num_u16000_layer_m2_mlp_fresh_rmse': 0.9800118525430588,
#  'emb128_num_u16000_layer_m4_mlp_train_rmse': 0.577592991570898,
#  'emb128_num_u16000_layer_m4_mlp_test_rmse': 1.04167609528407,
#  'emb128_num_u16000_layer_m4_mlp_fresh_rmse': 1.0589999162243457,
#  'emb128_num_u32000_layer_m1_mlp_train_rmse': 0.8551584316722796,
#  'emb128_num_u32000_layer_m1_mlp_test_rmse': 0.9152283040267432,
#  'emb128_num_u32000_layer_m1_mlp_fresh_rmse': 0.9256011530182365,
#  'emb128_num_u32000_layer_m2_mlp_train_rmse': 0.8051891059767681,
#  'emb128_num_u32000_layer_m2_mlp_test_rmse': 0.9157354255722445,
#  'emb128_num_u32000_layer_m2_mlp_fresh_rmse': 0.9234776870580632,
#  'emb128_num_u32000_layer_m4_mlp_train_rmse': 0.7211371874719174,
#  'emb128_num_u32000_layer_m4_mlp_test_rmse': 0.946188024711098,
#  'emb128_num_u32000_layer_m4_mlp_fresh_rmse': 0.9543325560399268}

# %%
import pandas as pd
df = pd.DataFrame.from_dict(results, orient='index', columns=['rmse'])

# %%
df.to_parquet('mlp_results.parquet')

# %%
df
# Out:
#                                                rmse
# emb16_num_u4000_layer_m1_mlp_train_rmse    0.889710
# emb16_num_u4000_layer_m1_mlp_test_rmse     0.900971
# emb16_num_u4000_layer_m1_mlp_fresh_rmse    0.899326
# emb16_num_u4000_layer_m2_mlp_train_rmse    0.854732
# emb16_num_u4000_layer_m2_mlp_test_rmse     0.876225
# ...                                             ...
# emb128_num_u32000_layer_m2_mlp_test_rmse   0.915735
# emb128_num_u32000_layer_m2_mlp_fresh_rmse  0.923478
# emb128_num_u32000_layer_m4_mlp_train_rmse  0.721137
# emb128_num_u32000_layer_m4_mlp_test_rmse   0.946188
# emb128_num_u32000_layer_m4_mlp_fresh_rmse  0.954333
#
# [144 rows x 1 columns]
